# %%
import numpy as np  # for array stuff and random
import random
import matplotlib.pyplot as plt  # for graphing our mean rewards over time
from matplotlib import style  # to make pretty charts because it matters.
import os

import torch
import gym
from gym import spaces
from gym import envs
from gym.utils import seeding, EzPickle

# %%
seed = 543 # Do not change this
def fix(env, seed):
    env.seed(seed)
    env.action_space.seed(seed)
    #torch.manual_seed(seed)
    #torch.cuda.manual_seed(seed)
    #torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    #torch.set_deterministic(True)
    #torch.backends.cudnn.benchmark = False
    #torch.backends.cudnn.deterministic = True

# %%
from stable_baselines3 import PPO
from stable_baselines3 import A2C

# %%
model = PPO.load("PPO_test14_modflow_multiInflow_coast")
#model = PPO.load("PPO_test_modflow_multiInflow_coast_MO_on3")
env = gym.make('pumpingAllocation-v5')

#Pick scenerio
scenerio = 10

p = [0]*10
p[scenerio-1] = 1
#p = [0,0,0,0,0,0,0,0.5, 0.5, 0]

env.river_p = p
env.demands_p = [1,0]

SW, GW, Sup, D = [], [], [], []
deficit=[]
S, h, inflow = [], [], []
Z_mean = []
rewards = []
env.ifRandtt = False

for i in range(1):
    print('----------test',i+1,'start-------------')
    state = env.reset()
    total_step=0
    while True:
        demand=env.demand
        
        action, _states = model.predict(state,deterministic=True )
        #print(action, _states)
        next_state, reward, done, info = env.step(action)
        #print(next_state,reward,done)
        
        #還原標準化
        month = (total_step//3)%12+1
        #month = (state[3]+1)/2*11+1
        #storage = (state[0]+1)/2*23500
        Zmin_before = (state[1]+1)/2*100-100
        Zmin_after = (next_state[1]+1)/2*100-100
        #demand = (state[2]+1)/2*(3006.85-1201.95+400)+1300-200
        
        inf = (state[4]+1)/2*(30721.8-336.2+200)+336.2-200
        
        storage = env.S
        sw = env.sw
        gw = action[1]*216*240*20/10000
        
        print(f'{month:2.0f}月, 第{total_step+1:2.0f}旬, 水庫水量:{storage:5.0f}, 水位(前、後):{Zmin_before:5.1f}→{Zmin_after:4.1f}, Action:{action}, SW、GW:[{sw:3.0f}, {gw:3.0f}], 需水量:{demand:4.0f}, Reward: {reward:.1f}')
        
        SW.append(sw)
        GW.append(gw)
        Sup.append(sw+gw)
        D.append(demand)
        deficit.append(demand-sw-gw)
        S.append(storage)
        h.append(Zmin_before)
        Z_mean.append(env.Zmean)
        inflow.append(inf)
        rewards.append(reward)
        
        
        state = next_state
        total_step+=1

        if done:
            break
# Out:
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ----------test 1 start-------------
#  1月, 第 1旬, 水庫水量:18113, 水位(前、後):  0.0→ 0.0, Action:[3 2], SW、GW:[900, 207], 需水量:1052, Reward: 1.8
#  1月, 第 2旬, 水庫水量:18372, 水位(前、後):  0.0→ 0.0, Action:[3 4], SW、GW:[900, 415], 需水量:1352, Reward: 0.9
#  1月, 第 3旬, 水庫水量:18231, 水位(前、後):  0.0→ 0.0, Action:[3 4], SW、GW:[900, 415], 需水量:1102, Reward: 1.4
#  2月, 第 4旬, 水庫水量:17379, 水位(前、後):  0.0→ 0.0, Action:[5 4], SW、GW:[1500, 415], 需水量:2265, Reward: 0.5
#  2月, 第 5旬, 水庫水量:16177, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2448, Reward: 1.9
#  2月, 第 6旬, 水庫水量:14282, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2828, Reward: 1.0
#  3月, 第 7旬, 水庫水量:12480, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3012, Reward: 1.8
#  3月, 第 8旬, 水庫水量:10774, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2863, Reward: 1.9
#  3月, 第 9旬, 水庫水量: 9203, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2999, Reward: 0.9
#  4月, 第10旬, 水庫水量: 7594, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2535, Reward: 1.0
#  4月, 第11旬, 水庫水量: 5766, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2666, Reward: 1.7
#  4月, 第12旬, 水庫水量: 4252, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2828, Reward: 1.9
#  5月, 第13旬, 水庫水量: 2951, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2502, Reward: 1.8
#  5月, 第14旬, 水庫水量: 1587, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2629, Reward: 2.0
#  5月, 第15旬, 水庫水量: 2103, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1587, 829], 需水量:2621, Reward: -2.0
#  6月, 第16旬, 水庫水量: 7073, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2538, Reward: 1.9
#  6月, 第17旬, 水庫水量: 9037, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2790, Reward: 1.8
#  6月, 第18旬, 水庫水量:11476, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2591, Reward: 0.9
#  7月, 第19旬, 水庫水量:11569, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2890, Reward: 2.0
#  7月, 第20旬, 水庫水量:10704, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3170, Reward: 1.9
#  7月, 第21旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2957, Reward: 1.0
#  8月, 第22旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2799, Reward: 2.8
#  8月, 第23旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:3117, Reward: 1.9
#  8月, 第24旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2752, Reward: 2.7
#  9月, 第25旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2763, Reward: 1.9
#  9月, 第26旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2453, Reward: 2.7
#  9月, 第27旬, 水庫水量:23327, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2687, Reward: 3.0
# 10月, 第28旬, 水庫水量:22270, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2718, Reward: 2.0
# 10月, 第29旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2918, Reward: 1.8
# 10月, 第30旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2666, Reward: 3.0
# 11月, 第31旬, 水庫水量:23299, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2506, Reward: 2.8
# 11月, 第32旬, 水庫水量:22328, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2542, Reward: 2.8
# 11月, 第33旬, 水庫水量:22265, 水位(前、後):  0.0→ 0.0, Action:[5 0], SW、GW:[1500,   0], 需水量:2310, Reward: 0.9
# 12月, 第34旬, 水庫水量:22162, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1402, Reward: 1.6
# 12月, 第35旬, 水庫水量:22133, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1002, Reward: 2.4
# 12月, 第36旬, 水庫水量:22193, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1252, Reward: 1.9
#  1月, 第37旬, 水庫水量:21956, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1302, Reward: 1.8
#  1月, 第38旬, 水庫水量:21865, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1152, Reward: 2.9
#  1月, 第39旬, 水庫水量:21425, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1152, Reward: 2.9
#  2月, 第40旬, 水庫水量:19772, 水位(前、後):  0.0→ 0.0, Action:[7 0], SW、GW:[2100,   0], 需水量:2365, Reward: 1.7
#  2月, 第41旬, 水庫水量:18070, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2648, Reward: 1.8
#  2月, 第42旬, 水庫水量:16075, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2528, Reward: 1.7
#  3月, 第43旬, 水庫水量:14323, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2712, Reward: 1.9
#  3月, 第44旬, 水庫水量:12418, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3013, Reward: 1.8
#  3月, 第45旬, 水庫水量:10596, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3149, Reward: 1.9
#  4月, 第46旬, 水庫水量: 8988, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2535, Reward: 1.0
#  4月, 第47旬, 水庫水量: 7210, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2516, Reward: 1.0
#  4月, 第48旬, 水庫水量: 5695, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2878, Reward: 1.9
#  5月, 第49旬, 水庫水量: 4444, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2452, Reward: 1.8
#  5月, 第50旬, 水庫水量: 2980, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2429, Reward: 1.8
#  5月, 第51旬, 水庫水量: 3333, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2521, Reward: 1.9
#  6月, 第52旬, 水庫水量: 8453, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2388, Reward: 1.7
#  6月, 第53旬, 水庫水量:10917, 水位(前、後):  0.0→ 0.0, Action:[6 4], SW、GW:[1800, 415], 需水量:2440, Reward: 0.7
#  6月, 第54旬, 水庫水量:13307, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2641, Reward: 0.9
#  7月, 第55旬, 水庫水量:13149, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:2990, Reward: 1.8
#  7月, 第56旬, 水庫水量:12334, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3020, Reward: 1.8
#  7月, 第57旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2807, Reward: 1.9
#  8月, 第58旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:3049, Reward: 2.0
#  8月, 第59旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2967, Reward: 3.0
#  8月, 第60旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2952, Reward: 3.0
#  9月, 第61旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2913, Reward: 1.8
#  9月, 第62旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2753, Reward: 1.9
#  9月, 第63旬, 水庫水量:23327, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2737, Reward: 2.0
# 10月, 第64旬, 水庫水量:22120, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2918, Reward: 1.8
# 10月, 第65旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2668, Reward: 3.0
# 10月, 第66旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2716, Reward: 2.0
# 11月, 第67旬, 水庫水量:23199, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2456, Reward: 2.7
# 11月, 第68旬, 水庫水量:22728, 水位(前、後):  0.0→ 0.0, Action:[7 0], SW、GW:[2100,   0], 需水量:2142, Reward: 1.9
# 11月, 第69旬, 水庫水量:22765, 水位(前、後):  0.0→ 0.0, Action:[5 0], SW、GW:[1500,   0], 需水量:2110, Reward: 1.1
# 12月, 第70旬, 水庫水量:22812, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1352, Reward: 1.7
# 12月, 第71旬, 水庫水量:22833, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1052, Reward: 2.6
# 12月, 第72旬, 水庫水量:22893, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1102, Reward: 2.7
#  1月, 第73旬, 水庫水量:22806, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1302, Reward: 1.8
#  1月, 第74旬, 水庫水量:22765, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1102, Reward: 2.7
#  1月, 第75旬, 水庫水量:22275, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1152, Reward: 2.9
#  2月, 第76旬, 水庫水量:20422, 水位(前、後):  0.0→ 0.0, Action:[8 0], SW、GW:[2400,   0], 需水量:2365, Reward: 3.0
#  2月, 第77旬, 水庫水量:18570, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2748, Reward: 0.9
#  2月, 第78旬, 水庫水量:16575, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2628, Reward: 1.8
#  3月, 第79旬, 水庫水量:14773, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2812, Reward: 2.0
#  3月, 第80旬, 水庫水量:12868, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2813, Reward: 2.0
#  3月, 第81旬, 水庫水量:11296, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2749, Reward: 0.7
#  4月, 第82旬, 水庫水量: 9488, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2835, Reward: 1.9
#  4月, 第83旬, 水庫水量: 7710, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2666, Reward: 1.7
#  4月, 第84旬, 水庫水量: 6145, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2728, Reward: 1.8
#  5月, 第85旬, 水庫水量: 4594, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2602, Reward: 0.6
#  5月, 第86旬, 水庫水量: 3180, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2579, Reward: 1.9
#  5月, 第87旬, 水庫水量: 3633, 水位(前、後):  0.0→ 0.0, Action:[6 4], SW、GW:[1800, 415], 需水量:2321, Reward: 0.9
#  6月, 第88旬, 水庫水量: 8303, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2788, Reward: 1.8
#  6月, 第89旬, 水庫水量:10667, 水位(前、後):  0.0→ 0.0, Action:[6 4], SW、GW:[1800, 415], 需水量:2490, Reward: 0.7
#  6月, 第90旬, 水庫水量:12957, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2841, Reward: 1.9
#  7月, 第91旬, 水庫水量:12749, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3090, Reward: 1.9
#  7月, 第92旬, 水庫水量:12234, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2820, Reward: 1.9
#  7月, 第93旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3007, Reward: 1.8
#  8月, 第94旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:3049, Reward: 2.0
#  8月, 第95旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2717, Reward: 2.7
#  8月, 第96旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2702, Reward: 2.7
#  9月, 第97旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2713, Reward: 2.0
#  9月, 第98旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2653, Reward: 2.9
#  9月, 第99旬, 水庫水量:23327, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2587, Reward: 2.9
# 10月, 第100旬, 水庫水量:22270, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2568, Reward: 2.8
# 10月, 第101旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2818, Reward: 1.9
# 10月, 第102旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2766, Reward: 1.9
# 11月, 第103旬, 水庫水量:23149, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2456, Reward: 2.7
# 11月, 第104旬, 水庫水量:22128, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2492, Reward: 2.7
# 11月, 第105旬, 水庫水量:22115, 水位(前、後):  0.0→ 0.0, Action:[5 0], SW、GW:[1500,   0], 需水量:1910, Reward: 1.4
# 12月, 第106旬, 水庫水量:21962, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1052, Reward: 2.6
# 12月, 第107旬, 水庫水量:21883, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1252, Reward: 1.9
# 12月, 第108旬, 水庫水量:21893, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1152, Reward: 2.9
#  1月, 第109旬, 水庫水量:21806, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1302, Reward: 1.8
#  1月, 第110旬, 水庫水量:21565, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1152, Reward: 2.9
#  1月, 第111旬, 水庫水量:21075, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1302, Reward: 1.8
#  2月, 第112旬, 水庫水量:19572, 水位(前、後):  0.0→ 0.0, Action:[7 0], SW、GW:[2100,   0], 需水量:2315, Reward: 0.7
#  2月, 第113旬, 水庫水量:18070, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2498, Reward: 0.6
#  2月, 第114旬, 水庫水量:16425, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2478, Reward: 2.0
#  3月, 第115旬, 水庫水量:14873, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2612, Reward: 0.9
#  3月, 第116旬, 水庫水量:12818, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2763, Reward: 1.9
#  3月, 第117旬, 水庫水量:11296, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2749, Reward: 0.7
#  4月, 第118旬, 水庫水量: 9488, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2585, Reward: 0.9
#  4月, 第119旬, 水庫水量: 7660, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2766, Reward: 1.8
#  4月, 第120旬, 水庫水量: 6195, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2728, Reward: 1.8
#  5月, 第121旬, 水庫水量: 4944, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2552, Reward: 1.9
#  5月, 第122旬, 水庫水量: 3430, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2479, Reward: 1.8
#  5月, 第123旬, 水庫水量: 3383, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2721, Reward: 1.8
#  6月, 第124旬, 水庫水量: 8503, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2638, Reward: 1.0
#  6月, 第125旬, 水庫水量:10667, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2740, Reward: 1.8
#  6月, 第126旬, 水庫水量:12907, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2791, Reward: 1.9
#  7月, 第127旬, 水庫水量:12649, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3140, Reward: 1.9
#  7月, 第128旬, 水庫水量:11734, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3070, Reward: 1.8
#  7月, 第129旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3107, Reward: 1.9
#  8月, 第130旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2749, Reward: 2.7
#  8月, 第131旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2767, Reward: 2.7
#  8月, 第132旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2852, Reward: 2.8
#  9月, 第133旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2863, Reward: 1.8
#  9月, 第134旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2653, Reward: 2.9
#  9月, 第135旬, 水庫水量:23377, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2687, Reward: 3.0
# 10月, 第136旬, 水庫水量:22270, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2818, Reward: 1.9
# 10月, 第137旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2668, Reward: 3.0
# 10月, 第138旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2716, Reward: 2.0
# 11月, 第139旬, 水庫水量:23199, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2406, Reward: 2.6
# 11月, 第140旬, 水庫水量:22878, 水位(前、後):  0.0→ 0.0, Action:[7 0], SW、GW:[2100,   0], 需水量:2192, Reward: 1.9
# 11月, 第141旬, 水庫水量:22815, 水位(前、後):  0.0→ 0.0, Action:[5 0], SW、GW:[1500,   0], 需水量:2160, Reward: 1.1
# 12月, 第142旬, 水庫水量:22712, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1302, Reward: 1.8
# 12月, 第143旬, 水庫水量:22633, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1102, Reward: 2.7
# 12月, 第144旬, 水庫水量:22643, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1402, Reward: 1.6
#  1月, 第145旬, 水庫水量:22456, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1402, Reward: 1.6
#  1月, 第146旬, 水庫水量:22265, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1002, Reward: 2.4
#  1月, 第147旬, 水庫水量:21875, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1302, Reward: 1.8
#  2月, 第148旬, 水庫水量:20422, 水位(前、後):  0.0→ 0.0, Action:[7 0], SW、GW:[2100,   0], 需水量:2265, Reward: 1.8
#  2月, 第149旬, 水庫水量:19070, 水位(前、後):  0.0→ 0.0, Action:[7 0], SW、GW:[2100,   0], 需水量:2398, Reward: 0.6
#  2月, 第150旬, 水庫水量:17175, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2828, Reward: 1.0
#  3月, 第151旬, 水庫水量:15373, 水位(前、後):  0.0→ 0.0, Action:[8 4], SW、GW:[2400, 415], 需水量:2612, Reward: 1.8
#  3月, 第152旬, 水庫水量:13368, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:2913, Reward: 0.7
#  3月, 第153旬, 水庫水量:11546, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:2999, Reward: 1.8
#  4月, 第154旬, 水庫水量: 9938, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2785, Reward: 1.8
#  4月, 第155旬, 水庫水量: 8160, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2566, Reward: 0.9
#  4月, 第156旬, 水庫水量: 6645, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2728, Reward: 1.8
#  5月, 第157旬, 水庫水量: 5244, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2502, Reward: 1.8
#  5月, 第158旬, 水庫水量: 3730, 水位(前、後):  0.0→ 0.0, Action:[6 4], SW、GW:[1800, 415], 需水量:2329, Reward: 0.9
#  5月, 第159旬, 水庫水量: 3833, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2721, Reward: 1.8
#  6月, 第160旬, 水庫水量: 8953, 水位(前、後):  0.0→ 0.0, Action:[6 8], SW、GW:[1800, 829], 需水量:2438, Reward: 1.8
#  6月, 第161旬, 水庫水量:11067, 水位(前、後):  0.0→ 0.0, Action:[7 8], SW、GW:[2100, 829], 需水量:2790, Reward: 1.8
#  6月, 第162旬, 水庫水量:13357, 水位(前、後):  0.0→ 0.0, Action:[7 4], SW、GW:[2100, 415], 需水量:2641, Reward: 0.9
#  7月, 第163旬, 水庫水量:13199, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3090, Reward: 1.9
#  7月, 第164旬, 水庫水量:12184, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3070, Reward: 1.8
#  7月, 第165旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[8 8], SW、GW:[2400, 829], 需水量:3157, Reward: 1.9
#  8月, 第166旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2899, Reward: 2.9
#  8月, 第167旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:2867, Reward: 2.9
#  8月, 第168旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[10  0], SW、GW:[3000,   0], 需水量:3052, Reward: 1.9
#  9月, 第169旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2513, Reward: 2.8
#  9月, 第170旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2753, Reward: 1.9
#  9月, 第171旬, 水庫水量:23377, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2887, Reward: 1.8
# 10月, 第172旬, 水庫水量:22370, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2718, Reward: 2.0
# 10月, 第173旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2968, Reward: 1.7
# 10月, 第174旬, 水庫水量:23500, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2666, Reward: 3.0
# 11月, 第175旬, 水庫水量:23299, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2756, Reward: 1.9
# 11月, 第176旬, 水庫水量:22278, 水位(前、後):  0.0→ 0.0, Action:[9 0], SW、GW:[2700,   0], 需水量:2492, Reward: 2.7
# 11月, 第177旬, 水庫水量:22365, 水位(前、後):  0.0→ 0.0, Action:[5 0], SW、GW:[1500,   0], 需水量:1910, Reward: 1.4
# 12月, 第178旬, 水庫水量:22362, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1402, Reward: 1.6
# 12月, 第179旬, 水庫水量:22383, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1252, Reward: 1.9
# 12月, 第180旬, 水庫水量:22443, 水位(前、後):  0.0→ 0.0, Action:[4 0], SW、GW:[1200,   0], 需水量:1002, Reward: 2.4

# %%
scenerio+=2011
# Out:
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import matplotlib.pyplot as plt
import pandas as pd
end=180
policy_type='_with extra bonus'

df = pd.DataFrame({'SW':SW[:end],
                   'GW':GW[:end],
                   'Supply':Sup[:end],
                   'Demand':D[:end],
                   'ith period of tendays':[i for i in range(1,end+1)],
                   'deficit':deficit[:end],
                   'Storage':S[:end],
                   'h_min':h[:end],
                   'Inflow':inflow[:end],
                   'deficit_rate':[(b-a)/b*100 for a,b in zip(Sup[:end],D[:end])],
                   'reward':rewards[:end],
                   'h_avg':Z_mean[:end]
                  }) 

file_name='Scenerio{}{}.csv'.format(scenerio,policy_type)
df.to_csv(file_name)

ax = df[['SW','GW']].plot(kind='bar', stacked=True, figsize=(18,6), width=0.7,
                          xlim=[1,180], ylim=[0,4100], xticks=[9*i for i in range(1,21)], fontsize=14)
df['Demand'].plot(kind='line', color='#FF0000', lw=2, xlim=[1,180],legend=True)
df['Supply'].plot(kind='line', style='g.-', lw=2, xlim=[1,180],legend=True)
ax.set_title('SW+GW__Scenerio{}{}'.format(scenerio,policy_type), fontsize=16)
ax.set_xlabel("tendays", fontsize=14)
ax.set_ylabel("volume  ($10^4$ $m^3$)", fontsize=14)
ax.legend()

plt.savefig('./SW+GW__Scenerio{}{}.jpg'.format(scenerio,policy_type) )
# Out:
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#reward
ax = df['reward'].plot(kind='bar', figsize=(15,5), lw=1.5, xlim=[1,180], ylim=[-5,3.5], 
                        style='r.-', xticks=[9*i for i in range(1,21)], fontsize=10)
#ax.set_title('deficit_rate', fontsize=16)
ax.set_xlabel("tendays", fontsize=14)
ax.set_ylabel("Reward", fontsize=14)
ax.set_title('Reward__Scenerio{}{}'.format(scenerio,policy_type), fontsize=16)

for i in range(6):
    ax.axvline(36*i, color="grey",lw=0.4, linestyle="dashed")


print(df['reward'].sum())
print(df['reward'].mean())

plt.savefig('./Reward__Scenerio{}{}.jpg'.format(scenerio,policy_type))
# Out:
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 337.47816485884454
# 1.8748786936602475

# %%
ax = df['deficit_rate'].plot(kind='bar', figsize=(15,5), lw=1.5, xlim=[1,180], ylim=[-100,100], 
                        style='r.-', xticks=[9*i for i in range(1,21)], fontsize=10)
ax.set_xlabel("tendays", fontsize=14)
ax.set_ylabel("WDR (%)", fontsize=14)
ax.set_title('Water deficient rate__Scenerio{}{}'.format(scenerio,policy_type), fontsize=16)

for i in range(6):
    ax.axvline(36*i, color="grey",lw=0.4, linestyle="dashed")
    
plt.savefig('./Water deficient rate__Scenerio{}{}.jpg'.format(scenerio,policy_type))
# Out:
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ax = df[['Storage','Inflow']].plot(kind='line', lw='2', figsize=(15,5),xlim=[1,180], ylim=[0,36000], xticks=[9*i for i in range(1,21)])
ax.set_title('Storage & Inflow__Scenerio{}{}'.format(scenerio,policy_type), fontsize=16)
ax.set_xlabel("tendays", fontsize=14)
ax.set_ylabel("volume  ($10^4$ $m^3$)", fontsize=14)
ax.legend()

for i in range(6):
    ax.axvline(36*i, color="grey",lw=0.4, linestyle="dashed")
    
plt.savefig('./Storage & Inflow__Scenerio{}{}.jpg'.format(scenerio,policy_type))
# Out:
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ax = df['GW'].plot(kind='bar', color='darkorange', figsize=(15,5), xlim=[1,180],ylim=[0,1000],width=0.4, xticks=[9*i for i in range(1,21)], legend=True)
ax2 = df['h_min'].plot(kind='line', secondary_y = True,  lw=2, color='#FF0000', legend=True)
ax3 = df['h_avg'].plot(kind='line', secondary_y = True,  lw=2, color='green', legend=True)
ax.set_title('GW pumping & Groundwater Head__Scenerio{}{}'.format(scenerio,policy_type), fontsize=16)
ax.set_xlabel("tendays", fontsize=14)
ax.set_ylabel("groundwater pumping  ($10^4$ $m^3$)", fontsize=14)

for i in range(6):
    ax.axvline(36*i, color="grey",lw=0.4, linestyle="dashed")
ax2.axhline(0, color="grey",lw=0.6, linestyle="dashed")
    
ax2.set_ylabel("groundwater head (m)", fontsize=14)
ax2.set_ylim(-50, 100)
ax.legend(loc=2)
ax2.legend(loc=1)

plt.savefig('./GW pumping & Groundwater Head__Scenerio{}{}.jpg'.format(scenerio,policy_type))
# Out:
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\compat.py:13: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   op(LooseVersion(mpl.__version__), LooseVersion(version))
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\compat.py:13: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   op(LooseVersion(mpl.__version__), LooseVersion(version))
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\compat.py:13: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   op(LooseVersion(mpl.__version__), LooseVersion(version))
# c:\users\hulab\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\compat.py:13: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   op(LooseVersion(mpl.__version__), LooseVersion(version))
