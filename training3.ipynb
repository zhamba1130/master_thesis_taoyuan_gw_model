# %%
import numpy as np  # for array stuff and random
import random
import matplotlib.pyplot as plt  # for graphing our mean rewards over time
from matplotlib import style  # to make pretty charts because it matters.
import os

import torch
import gym
from gym import spaces
from gym import envs
from gym.utils import seeding, EzPickle

# %%
seed = 543 # Do not change this
def fix(env, seed):
    env.seed(seed)
    env.action_space.seed(seed)
    #torch.manual_seed(seed)
    #torch.cuda.manual_seed(seed)
    #torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    #torch.set_deterministic(True)
    #torch.backends.cudnn.benchmark = False
    #torch.backends.cudnn.deterministic = True

# %%
from stable_baselines3 import PPO
from stable_baselines3 import A2C

# %%
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.logger import configure

env = gym.make('pumpingAllocation-v4')
#Parallel environments
#env = make_vec_env('pumpingAllocation-v1', n_envs=8)
fix(env, seed)

tmp_path = "./PPO_square_no_bonus/"
# set up logger
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

model = PPO("MlpPolicy", env, verbose=1, n_steps=3600, seed=seed)
model.set_logger(new_logger)
model.learn(total_timesteps=360000)
# Out:
# Logging to ./PPO_square_no_bonus/
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\johnn\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\johnn\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\ppo\ppo.py:148: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3600`, after every 56 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3600 and n_envs=1)
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -87.2    |
# | time/              |          |
# |    fps             | 8        |
# |    iterations      | 1        |
# |    time_elapsed    | 416      |
# |    total_timesteps | 3600     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -70.7       |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 2           |
# |    time_elapsed         | 826         |
# |    total_timesteps      | 7200        |
# | train/                  |             |
# |    approx_kl            | 0.013746567 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.79       |
# |    explained_variance   | 0.000886    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.6        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 37.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | -58.5      |
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 3          |
# |    time_elapsed         | 1249       |
# |    total_timesteps      | 10800      |
# | train/                  |            |
# |    approx_kl            | 0.01383356 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.75      |
# |    explained_variance   | -0.00768   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.68       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0228    |
# |    value_loss           | 28.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -41.9       |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 4           |
# |    time_elapsed         | 1658        |
# |    total_timesteps      | 14400       |
# | train/                  |             |
# |    approx_kl            | 0.015044241 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.00884     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 25.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -28.2       |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 5           |
# |    time_elapsed         | 2113        |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.015450823 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | -0.00127    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.39        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 19.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -0.722      |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 6           |
# |    time_elapsed         | 2598        |
# |    total_timesteps      | 21600       |
# | train/                  |             |
# |    approx_kl            | 0.016686944 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.0143      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.35        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 22.9        |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 7           |
# |    time_elapsed         | 3132        |
# |    total_timesteps      | 25200       |
# | train/                  |             |
# |    approx_kl            | 0.017901834 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.0511      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.55        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 13.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 46.6        |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 8           |
# |    time_elapsed         | 3704        |
# |    total_timesteps      | 28800       |
# | train/                  |             |
# |    approx_kl            | 0.013994326 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.00646     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.86        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 64.1       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 9          |
# |    time_elapsed         | 4183       |
# |    total_timesteps      | 32400      |
# | train/                  |            |
# |    approx_kl            | 0.01129805 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.27      |
# |    explained_variance   | 0.0104     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.6       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0122    |
# |    value_loss           | 20.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 79.9        |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 10          |
# |    time_elapsed         | 4651        |
# |    total_timesteps      | 36000       |
# | train/                  |             |
# |    approx_kl            | 0.013783549 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.0284      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 26.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 92.2         |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 11           |
# |    time_elapsed         | 5124         |
# |    total_timesteps      | 39600        |
# | train/                  |              |
# |    approx_kl            | 0.0124206655 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.1         |
# |    explained_variance   | 0.0327       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.8         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 32.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 103         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 12          |
# |    time_elapsed         | 5614        |
# |    total_timesteps      | 43200       |
# | train/                  |             |
# |    approx_kl            | 0.010914753 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.0317      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.6        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00698    |
# |    value_loss           | 39.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 13          |
# |    time_elapsed         | 6084        |
# |    total_timesteps      | 46800       |
# | train/                  |             |
# |    approx_kl            | 0.010944087 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.0568      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00855    |
# |    value_loss           | 47.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 14          |
# |    time_elapsed         | 6551        |
# |    total_timesteps      | 50400       |
# | train/                  |             |
# |    approx_kl            | 0.010278171 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.0034      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00861    |
# |    value_loss           | 59          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 119         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 15          |
# |    time_elapsed         | 7022        |
# |    total_timesteps      | 54000       |
# | train/                  |             |
# |    approx_kl            | 0.010447099 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.0357      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.4        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00884    |
# |    value_loss           | 63.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 124        |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 16         |
# |    time_elapsed         | 7495       |
# |    total_timesteps      | 57600      |
# | train/                  |            |
# |    approx_kl            | 0.01031536 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.86      |
# |    explained_variance   | 0.0664     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 71.4       |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00946   |
# |    value_loss           | 73.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 17          |
# |    time_elapsed         | 7966        |
# |    total_timesteps      | 61200       |
# | train/                  |             |
# |    approx_kl            | 0.010828653 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.0799      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.7        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00934    |
# |    value_loss           | 78.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 18           |
# |    time_elapsed         | 8449         |
# |    total_timesteps      | 64800        |
# | train/                  |              |
# |    approx_kl            | 0.0128714545 |
# |    clip_fraction        | 0.164        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.76        |
# |    explained_variance   | 0.0798       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.8         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 86.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 19          |
# |    time_elapsed         | 8923        |
# |    total_timesteps      | 68400       |
# | train/                  |             |
# |    approx_kl            | 0.010258199 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.0489      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.3        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00853    |
# |    value_loss           | 90.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 20          |
# |    time_elapsed         | 9403        |
# |    total_timesteps      | 72000       |
# | train/                  |             |
# |    approx_kl            | 0.009467323 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.0136      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00691    |
# |    value_loss           | 98.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 21          |
# |    time_elapsed         | 9887        |
# |    total_timesteps      | 75600       |
# | train/                  |             |
# |    approx_kl            | 0.012827046 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.00554     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.5        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 22          |
# |    time_elapsed         | 10376       |
# |    total_timesteps      | 79200       |
# | train/                  |             |
# |    approx_kl            | 0.010526975 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.0137      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 121         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 109         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 146        |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 23         |
# |    time_elapsed         | 10862      |
# |    total_timesteps      | 82800      |
# | train/                  |            |
# |    approx_kl            | 0.01012321 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | 0.0271     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.26       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00923   |
# |    value_loss           | 118        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 149         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 24          |
# |    time_elapsed         | 11348       |
# |    total_timesteps      | 86400       |
# | train/                  |             |
# |    approx_kl            | 0.011397252 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.0277      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.8        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 117         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 152        |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 25         |
# |    time_elapsed         | 11840      |
# |    total_timesteps      | 90000      |
# | train/                  |            |
# |    approx_kl            | 0.01210712 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0.0231     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 79.3       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0087    |
# |    value_loss           | 126        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 155        |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 26         |
# |    time_elapsed         | 12326      |
# |    total_timesteps      | 93600      |
# | train/                  |            |
# |    approx_kl            | 0.00963074 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.32      |
# |    explained_variance   | 0.0328     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 53.1       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.00689   |
# |    value_loss           | 127        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 159         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 27          |
# |    time_elapsed         | 12812       |
# |    total_timesteps      | 97200       |
# | train/                  |             |
# |    approx_kl            | 0.011828443 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.0311      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00782    |
# |    value_loss           | 134         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 163         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 28          |
# |    time_elapsed         | 13301       |
# |    total_timesteps      | 100800      |
# | train/                  |             |
# |    approx_kl            | 0.010114637 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.0389      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 159         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00978    |
# |    value_loss           | 145         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 167         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 29          |
# |    time_elapsed         | 13789       |
# |    total_timesteps      | 104400      |
# | train/                  |             |
# |    approx_kl            | 0.011294098 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.0426      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 150         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 30          |
# |    time_elapsed         | 14306       |
# |    total_timesteps      | 108000      |
# | train/                  |             |
# |    approx_kl            | 0.011837334 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.037       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 145         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00904    |
# |    value_loss           | 155         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 31          |
# |    time_elapsed         | 14815       |
# |    total_timesteps      | 111600      |
# | train/                  |             |
# |    approx_kl            | 0.008834354 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.0708      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 102         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 166         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 176         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 32          |
# |    time_elapsed         | 15291       |
# |    total_timesteps      | 115200      |
# | train/                  |             |
# |    approx_kl            | 0.010092198 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | 0.0113      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00534    |
# |    value_loss           | 169         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 180         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 33          |
# |    time_elapsed         | 15767       |
# |    total_timesteps      | 118800      |
# | train/                  |             |
# |    approx_kl            | 0.008951301 |
# |    clip_fraction        | 0.0802      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.0437      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.2        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 177         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 34          |
# |    time_elapsed         | 16243       |
# |    total_timesteps      | 122400      |
# | train/                  |             |
# |    approx_kl            | 0.011610636 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.0395      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 208         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00941    |
# |    value_loss           | 179         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 180         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 35          |
# |    time_elapsed         | 16723       |
# |    total_timesteps      | 126000      |
# | train/                  |             |
# |    approx_kl            | 0.009128488 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.0754      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.6        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 190         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 36          |
# |    time_elapsed         | 17204       |
# |    total_timesteps      | 129600      |
# | train/                  |             |
# |    approx_kl            | 0.010398515 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.096       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.4        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00762    |
# |    value_loss           | 184         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 181          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 37           |
# |    time_elapsed         | 17684        |
# |    total_timesteps      | 133200       |
# | train/                  |              |
# |    approx_kl            | 0.0120306695 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.0503       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 241          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0089      |
# |    value_loss           | 199          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 183         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 38          |
# |    time_elapsed         | 18166       |
# |    total_timesteps      | 136800      |
# | train/                  |             |
# |    approx_kl            | 0.010583382 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.0949      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 182         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00651    |
# |    value_loss           | 199         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 186         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 39          |
# |    time_elapsed         | 18645       |
# |    total_timesteps      | 140400      |
# | train/                  |             |
# |    approx_kl            | 0.008703487 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.0493      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.1        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00636    |
# |    value_loss           | 202         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 190         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 40          |
# |    time_elapsed         | 19125       |
# |    total_timesteps      | 144000      |
# | train/                  |             |
# |    approx_kl            | 0.008655822 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.028       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 128         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 203         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 195         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 41          |
# |    time_elapsed         | 19604       |
# |    total_timesteps      | 147600      |
# | train/                  |             |
# |    approx_kl            | 0.009592568 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.053       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.7        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0084     |
# |    value_loss           | 205         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 42          |
# |    time_elapsed         | 20087       |
# |    total_timesteps      | 151200      |
# | train/                  |             |
# |    approx_kl            | 0.009507438 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.0295      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 191         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 219         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 43          |
# |    time_elapsed         | 20568       |
# |    total_timesteps      | 154800      |
# | train/                  |             |
# |    approx_kl            | 0.008753027 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | 0.0483      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 107         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00844    |
# |    value_loss           | 220         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 44          |
# |    time_elapsed         | 21046       |
# |    total_timesteps      | 158400      |
# | train/                  |             |
# |    approx_kl            | 0.008043188 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.034       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 221         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 201         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 45          |
# |    time_elapsed         | 21520       |
# |    total_timesteps      | 162000      |
# | train/                  |             |
# |    approx_kl            | 0.009924784 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.0263      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.7        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 225         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 46           |
# |    time_elapsed         | 21997        |
# |    total_timesteps      | 165600       |
# | train/                  |              |
# |    approx_kl            | 0.0095447395 |
# |    clip_fraction        | 0.0944       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.0321       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.5         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0064      |
# |    value_loss           | 222          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 201        |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 47         |
# |    time_elapsed         | 22473      |
# |    total_timesteps      | 169200     |
# | train/                  |            |
# |    approx_kl            | 0.01101237 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.35      |
# |    explained_variance   | 0.0362     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 259        |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00713   |
# |    value_loss           | 219        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 202          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 48           |
# |    time_elapsed         | 22952        |
# |    total_timesteps      | 172800       |
# | train/                  |              |
# |    approx_kl            | 0.0105403755 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.0259       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.4         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00418     |
# |    value_loss           | 226          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 203         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 49          |
# |    time_elapsed         | 23427       |
# |    total_timesteps      | 176400      |
# | train/                  |             |
# |    approx_kl            | 0.010758408 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.0373      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.8        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 224         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 50          |
# |    time_elapsed         | 23904       |
# |    total_timesteps      | 180000      |
# | train/                  |             |
# |    approx_kl            | 0.009873742 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.0248      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 146         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00905    |
# |    value_loss           | 234         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 51          |
# |    time_elapsed         | 24382       |
# |    total_timesteps      | 183600      |
# | train/                  |             |
# |    approx_kl            | 0.010318552 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.0578      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 230         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 205          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 52           |
# |    time_elapsed         | 24860        |
# |    total_timesteps      | 187200       |
# | train/                  |              |
# |    approx_kl            | 0.0070167514 |
# |    clip_fraction        | 0.0881       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.0464       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 166          |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00475     |
# |    value_loss           | 248          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 53          |
# |    time_elapsed         | 25335       |
# |    total_timesteps      | 190800      |
# | train/                  |             |
# |    approx_kl            | 0.009678577 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.0571      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 74.1        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00554    |
# |    value_loss           | 234         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 205          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 54           |
# |    time_elapsed         | 25815        |
# |    total_timesteps      | 194400       |
# | train/                  |              |
# |    approx_kl            | 0.0114314705 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 0.0616       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.5         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00657     |
# ...
# |    ep_rew_mean          | 225         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 83          |
# |    time_elapsed         | 39697       |
# |    total_timesteps      | 298800      |
# | train/                  |             |
# |    approx_kl            | 0.011954191 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.0396      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 368         |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00806    |
# |    value_loss           | 297         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 226         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 84          |
# |    time_elapsed         | 40185       |
# |    total_timesteps      | 302400      |
# | train/                  |             |
# |    approx_kl            | 0.006222495 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.0406      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 133         |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00493    |
# |    value_loss           | 305         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 85          |
# |    time_elapsed         | 40673       |
# |    total_timesteps      | 306000      |
# | train/                  |             |
# |    approx_kl            | 0.008864844 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.0302      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75          |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00615    |
# |    value_loss           | 302         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 229          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 86           |
# |    time_elapsed         | 41156        |
# |    total_timesteps      | 309600       |
# | train/                  |              |
# |    approx_kl            | 0.0074703125 |
# |    clip_fraction        | 0.0908       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.0376       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.1         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00487     |
# |    value_loss           | 302          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 87           |
# |    time_elapsed         | 41637        |
# |    total_timesteps      | 313200       |
# | train/                  |              |
# |    approx_kl            | 0.0099298535 |
# |    clip_fraction        | 0.0878       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.0389       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 164          |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00493     |
# |    value_loss           | 308          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 88           |
# |    time_elapsed         | 42120        |
# |    total_timesteps      | 316800       |
# | train/                  |              |
# |    approx_kl            | 0.0058779493 |
# |    clip_fraction        | 0.0986       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0321       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 97.8         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 310          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 89           |
# |    time_elapsed         | 42604        |
# |    total_timesteps      | 320400       |
# | train/                  |              |
# |    approx_kl            | 0.0074159964 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0358       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0076      |
# |    value_loss           | 314          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 90           |
# |    time_elapsed         | 43084        |
# |    total_timesteps      | 324000       |
# | train/                  |              |
# |    approx_kl            | 0.0056354986 |
# |    clip_fraction        | 0.0738       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0523       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 347          |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00384     |
# |    value_loss           | 320          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 233         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 91          |
# |    time_elapsed         | 43563       |
# |    total_timesteps      | 327600      |
# | train/                  |             |
# |    approx_kl            | 0.008074371 |
# |    clip_fraction        | 0.0857      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.073       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.9        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00595    |
# |    value_loss           | 308         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 233          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 92           |
# |    time_elapsed         | 44048        |
# |    total_timesteps      | 331200       |
# | train/                  |              |
# |    approx_kl            | 0.0074987207 |
# |    clip_fraction        | 0.0967       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.0689       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.8         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00643     |
# |    value_loss           | 321          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 93          |
# |    time_elapsed         | 44527       |
# |    total_timesteps      | 334800      |
# | train/                  |             |
# |    approx_kl            | 0.009099726 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.0563      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42          |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00635    |
# |    value_loss           | 322         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 94           |
# |    time_elapsed         | 45009        |
# |    total_timesteps      | 338400       |
# | train/                  |              |
# |    approx_kl            | 0.0056043565 |
# |    clip_fraction        | 0.0834       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0482       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 222          |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0053      |
# |    value_loss           | 320          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 95          |
# |    time_elapsed         | 45493       |
# |    total_timesteps      | 342000      |
# | train/                  |             |
# |    approx_kl            | 0.007637483 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.0491      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 122         |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 329         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 232         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 96          |
# |    time_elapsed         | 45976       |
# |    total_timesteps      | 345600      |
# | train/                  |             |
# |    approx_kl            | 0.006183029 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0502      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.6        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00375    |
# |    value_loss           | 322         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 233          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 97           |
# |    time_elapsed         | 46456        |
# |    total_timesteps      | 349200       |
# | train/                  |              |
# |    approx_kl            | 0.0061021177 |
# |    clip_fraction        | 0.0813       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.0898       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.7         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00695     |
# |    value_loss           | 339          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 98           |
# |    time_elapsed         | 46940        |
# |    total_timesteps      | 352800       |
# | train/                  |              |
# |    approx_kl            | 0.0077115777 |
# |    clip_fraction        | 0.0889       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.0543       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 235          |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.00681     |
# |    value_loss           | 335          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 99          |
# |    time_elapsed         | 47426       |
# |    total_timesteps      | 356400      |
# | train/                  |             |
# |    approx_kl            | 0.005355725 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0584      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.8        |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.00296    |
# |    value_loss           | 337         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 100          |
# |    time_elapsed         | 47915        |
# |    total_timesteps      | 360000       |
# | train/                  |              |
# |    approx_kl            | 0.0055941464 |
# |    clip_fraction        | 0.0747       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0339       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 189          |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.00402     |
# |    value_loss           | 324          |
# ------------------------------------------

# %%
model.save("PPO_square_no_bonus")

# %%
model.learn(total_timesteps=360000, tb_log_name="second_run", reset_num_timesteps=False)
model.save("PPO_square_no_bonus_2")
# Out:
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 1           |
# |    time_elapsed         | 478         |
# |    total_timesteps      | 363600      |
# | train/                  |             |
# |    approx_kl            | 0.007349644 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.0287      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.4        |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.00525    |
# |    value_loss           | 340         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 236          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 2            |
# |    time_elapsed         | 964          |
# |    total_timesteps      | 367200       |
# | train/                  |              |
# |    approx_kl            | 0.0055499747 |
# |    clip_fraction        | 0.0788       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.0419       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 189          |
# |    n_updates            | 1010         |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 326          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 3           |
# |    time_elapsed         | 1448        |
# |    total_timesteps      | 370800      |
# | train/                  |             |
# |    approx_kl            | 0.006809107 |
# |    clip_fraction        | 0.074       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.0555      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 213         |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 341         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 4            |
# |    time_elapsed         | 1934         |
# |    total_timesteps      | 374400       |
# | train/                  |              |
# |    approx_kl            | 0.0056195124 |
# |    clip_fraction        | 0.0635       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.0956       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 144          |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | -0.00546     |
# |    value_loss           | 332          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 236          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 5            |
# |    time_elapsed         | 2419         |
# |    total_timesteps      | 378000       |
# | train/                  |              |
# |    approx_kl            | 0.0054569147 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.0612       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 309          |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 346          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 6           |
# |    time_elapsed         | 2907        |
# |    total_timesteps      | 381600      |
# | train/                  |             |
# |    approx_kl            | 0.005741242 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0187      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 140         |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 322         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 7            |
# |    time_elapsed         | 3391         |
# |    total_timesteps      | 385200       |
# | train/                  |              |
# |    approx_kl            | 0.0075981407 |
# |    clip_fraction        | 0.0907       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.0445       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 79.7         |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | -0.00616     |
# |    value_loss           | 349          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 240         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 8           |
# |    time_elapsed         | 3876        |
# |    total_timesteps      | 388800      |
# | train/                  |             |
# |    approx_kl            | 0.006861342 |
# |    clip_fraction        | 0.0615      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.0656      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.2        |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | -0.00261    |
# |    value_loss           | 352         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 9            |
# |    time_elapsed         | 4360         |
# |    total_timesteps      | 392400       |
# | train/                  |              |
# |    approx_kl            | 0.0052302964 |
# |    clip_fraction        | 0.0779       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.0505       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 116          |
# |    n_updates            | 1080         |
# |    policy_gradient_loss | -0.00602     |
# |    value_loss           | 347          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 10           |
# |    time_elapsed         | 4842         |
# |    total_timesteps      | 396000       |
# | train/                  |              |
# |    approx_kl            | 0.0058803395 |
# |    clip_fraction        | 0.0802       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.0637       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 162          |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.00638     |
# |    value_loss           | 348          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 11           |
# |    time_elapsed         | 5324         |
# |    total_timesteps      | 399600       |
# | train/                  |              |
# |    approx_kl            | 0.0059898933 |
# |    clip_fraction        | 0.0725       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.0484       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 220          |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 333          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 12          |
# |    time_elapsed         | 5808        |
# |    total_timesteps      | 403200      |
# | train/                  |             |
# |    approx_kl            | 0.007430893 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0605      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77.3        |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.00533    |
# |    value_loss           | 353         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 13          |
# |    time_elapsed         | 6288        |
# |    total_timesteps      | 406800      |
# | train/                  |             |
# |    approx_kl            | 0.009605944 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0482      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.1        |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00455    |
# |    value_loss           | 346         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 14           |
# |    time_elapsed         | 6771         |
# |    total_timesteps      | 410400       |
# | train/                  |              |
# |    approx_kl            | 0.0073736296 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.0611       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 330          |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 358          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 240        |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 15         |
# |    time_elapsed         | 7252       |
# |    total_timesteps      | 414000     |
# | train/                  |            |
# |    approx_kl            | 0.00668094 |
# |    clip_fraction        | 0.0788     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.0675     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 67.5       |
# |    n_updates            | 1140       |
# |    policy_gradient_loss | -0.00516   |
# |    value_loss           | 369        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 240         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 16          |
# |    time_elapsed         | 7724        |
# |    total_timesteps      | 417600      |
# | train/                  |             |
# |    approx_kl            | 0.006882429 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.072       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 151         |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 354         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 17           |
# |    time_elapsed         | 8198         |
# |    total_timesteps      | 421200       |
# | train/                  |              |
# |    approx_kl            | 0.0039443267 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0651       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 101          |
# |    n_updates            | 1160         |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 351          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 18           |
# |    time_elapsed         | 8671         |
# |    total_timesteps      | 424800       |
# | train/                  |              |
# |    approx_kl            | 0.0060297344 |
# |    clip_fraction        | 0.0686       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.0757       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 177          |
# |    n_updates            | 1170         |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 347          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 238          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 19           |
# |    time_elapsed         | 9148         |
# |    total_timesteps      | 428400       |
# | train/                  |              |
# |    approx_kl            | 0.0057058157 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.047        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.3         |
# |    n_updates            | 1180         |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 349          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 240         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 20          |
# |    time_elapsed         | 9626        |
# |    total_timesteps      | 432000      |
# | train/                  |             |
# |    approx_kl            | 0.005549491 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.0328      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 338         |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 349         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 241         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 21          |
# |    time_elapsed         | 10105       |
# |    total_timesteps      | 435600      |
# | train/                  |             |
# |    approx_kl            | 0.007329106 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0467      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 165         |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 348         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 22           |
# |    time_elapsed         | 10590        |
# |    total_timesteps      | 439200       |
# | train/                  |              |
# |    approx_kl            | 0.0051370542 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.063        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 96.8         |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 345          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 23           |
# |    time_elapsed         | 11068        |
# |    total_timesteps      | 442800       |
# | train/                  |              |
# |    approx_kl            | 0.0076363343 |
# |    clip_fraction        | 0.0639       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.0641       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 267          |
# |    n_updates            | 1220         |
# |    policy_gradient_loss | -0.00451     |
# |    value_loss           | 363          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 24           |
# |    time_elapsed         | 11551        |
# |    total_timesteps      | 446400       |
# | train/                  |              |
# |    approx_kl            | 0.0057900026 |
# |    clip_fraction        | 0.062        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.997       |
# |    explained_variance   | 0.0451       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 180          |
# |    n_updates            | 1230         |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 353          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 249        |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 25         |
# |    time_elapsed         | 12033      |
# |    total_timesteps      | 450000     |
# | train/                  |            |
# |    approx_kl            | 0.00609834 |
# |    clip_fraction        | 0.0679     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.0436     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 351        |
# |    n_updates            | 1240       |
# |    policy_gradient_loss | -0.00387   |
# |    value_loss           | 340        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 26           |
# |    time_elapsed         | 12517        |
# |    total_timesteps      | 453600       |
# | train/                  |              |
# |    approx_kl            | 0.0046518524 |
# |    clip_fraction        | 0.0598       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.994       |
# |    explained_variance   | 0.0621       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 319          |
# |    n_updates            | 1250         |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 357          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 27          |
# |    time_elapsed         | 13000       |
# |    total_timesteps      | 457200      |
# | train/                  |             |
# |    approx_kl            | 0.005751443 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 0.0531      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.1        |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 357         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 28           |
# |    time_elapsed         | 13480        |
# |    total_timesteps      | 460800       |
# | train/                  |              |
# |    approx_kl            | 0.0067052688 |
# |    clip_fraction        | 0.0714       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.0811       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 180          |
# |    n_updates            | 1270         |
# |    policy_gradient_loss | -0.00544     |
# |    value_loss           | 374          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 29          |
# |    time_elapsed         | 13960       |
# |    total_timesteps      | 464400      |
# | train/                  |             |
# |    approx_kl            | 0.004540328 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.029       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49          |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 375         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 30          |
# |    time_elapsed         | 14438       |
# |    total_timesteps      | 468000      |
# | train/                  |             |
# |    approx_kl            | 0.008119836 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.8        |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 361         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 31           |
# |    time_elapsed         | 14918        |
# |    total_timesteps      | 471600       |
# | train/                  |              |
# |    approx_kl            | 0.0059361835 |
# |    clip_fraction        | 0.0647       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.961       |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.00419     |
# |    value_loss           | 370          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 32           |
# |    time_elapsed         | 15399        |
# |    total_timesteps      | 475200       |
# | train/                  |              |
# |    approx_kl            | 0.0065769856 |
# |    clip_fraction        | 0.0623       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.968       |
# |    explained_variance   | 0.0526       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 304          |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | -0.00492     |
# |    value_loss           | 372          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 33           |
# |    time_elapsed         | 15885        |
# |    total_timesteps      | 478800       |
# | train/                  |              |
# |    approx_kl            | 0.0044832216 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.977       |
# |    explained_variance   | 0.0561       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 69.8         |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 365          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 34           |
# |    time_elapsed         | 16372        |
# |    total_timesteps      | 482400       |
# | train/                  |              |
# |    approx_kl            | 0.0057126624 |
# |    clip_fraction        | 0.0777       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.0803       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 127          |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.005       |
# |    value_loss           | 369          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 249        |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 35         |
# |    time_elapsed         | 16860      |
# |    total_timesteps      | 486000     |
# | train/                  |            |
# |    approx_kl            | 0.00506766 |
# |    clip_fraction        | 0.0699     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.992     |
# |    explained_variance   | 0.0616     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 39.6       |
# |    n_updates            | 1340       |
# |    policy_gradient_loss | -0.00389   |
# |    value_loss           | 375        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 36           |
# |    time_elapsed         | 17348        |
# |    total_timesteps      | 489600       |
# | train/                  |              |
# |    approx_kl            | 0.0064186165 |
# |    clip_fraction        | 0.0742       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | 0.0503       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 193          |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 365          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 37           |
# |    time_elapsed         | 17836        |
# |    total_timesteps      | 493200       |
# | train/                  |              |
# |    approx_kl            | 0.0057811467 |
# |    clip_fraction        | 0.0689       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.981       |
# |    explained_variance   | 0.059        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 140          |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 366          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 38          |
# |    time_elapsed         | 18325       |
# |    total_timesteps      | 496800      |
# | train/                  |             |
# |    approx_kl            | 0.009772252 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | 0.0253      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79          |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 364         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 39           |
# |    time_elapsed         | 18822        |
# |    total_timesteps      | 500400       |
# | train/                  |              |
# |    approx_kl            | 0.0046176226 |
# |    clip_fraction        | 0.0656       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.971       |
# |    explained_variance   | 0.0452       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 309          |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00359     |
# |    value_loss           | 371          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 246         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 40          |
# |    time_elapsed         | 19319       |
# |    total_timesteps      | 504000      |
# | train/                  |             |
# |    approx_kl            | 0.004995398 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | 0.0732      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 319         |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.0035     |
# |    value_loss           | 369         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 41          |
# |    time_elapsed         | 19816       |
# |    total_timesteps      | 507600      |
# | train/                  |             |
# |    approx_kl            | 0.006246875 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.0727      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 247         |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 376         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 42           |
# |    time_elapsed         | 20312        |
# |    total_timesteps      | 511200       |
# | train/                  |              |
# |    approx_kl            | 0.0064454707 |
# |    clip_fraction        | 0.0763       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.926       |
# |    explained_variance   | 0.0376       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 95.9         |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.00512     |
# |    value_loss           | 382          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 43          |
# |    time_elapsed         | 20806       |
# |    total_timesteps      | 514800      |
# | train/                  |             |
# |    approx_kl            | 0.006867634 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.0436      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 147         |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.00292    |
# |    value_loss           | 369         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 44           |
# |    time_elapsed         | 21302        |
# |    total_timesteps      | 518400       |
# | train/                  |              |
# |    approx_kl            | 0.0073042093 |
# |    clip_fraction        | 0.0594       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.0417       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 245          |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 373          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 45           |
# |    time_elapsed         | 21808        |
# |    total_timesteps      | 522000       |
# | train/                  |              |
# |    approx_kl            | 0.0051197615 |
# |    clip_fraction        | 0.074        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.876       |
# |    explained_variance   | 0.0318       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 171          |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 384          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 46           |
# |    time_elapsed         | 22305        |
# |    total_timesteps      | 525600       |
# | train/                  |              |
# |    approx_kl            | 0.0043824962 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.871       |
# |    explained_variance   | 0.0384       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 362          |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 380          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 47          |
# |    time_elapsed         | 22799       |
# |    total_timesteps      | 529200      |
# | train/                  |             |
# |    approx_kl            | 0.004978833 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.0717      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 154         |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | -0.00392    |
# |    value_loss           | 378         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 48          |
# |    time_elapsed         | 23293       |
# |    total_timesteps      | 532800      |
# | train/                  |             |
# |    approx_kl            | 0.007722466 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.824      |
# |    explained_variance   | 0.052       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 116         |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | -0.00546    |
# |    value_loss           | 385         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 258          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 49           |
# |    time_elapsed         | 23789        |
# |    total_timesteps      | 536400       |
# | train/                  |              |
# |    approx_kl            | 0.0048930864 |
# |    clip_fraction        | 0.0694       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.0611       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 1480         |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 395          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 50           |
# |    time_elapsed         | 24283        |
# |    total_timesteps      | 540000       |
# | train/                  |              |
# |    approx_kl            | 0.0042395582 |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | 0.0459       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 123          |
# |    n_updates            | 1490         |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 391          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 51          |
# |    time_elapsed         | 24777       |
# |    total_timesteps      | 543600      |
# | train/                  |             |
# |    approx_kl            | 0.005632596 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | 0.0494      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 268         |
# |    n_updates            | 1500        |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 419         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 52           |
# |    time_elapsed         | 25270        |
# |    total_timesteps      | 547200       |
# | train/                  |              |
# |    approx_kl            | 0.0072738905 |
# |    clip_fraction        | 0.0761       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.832       |
# |    explained_variance   | 0.0286       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 133          |
# |    n_updates            | 1510         |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 385          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 53          |
# |    time_elapsed         | 25768       |
# |    total_timesteps      | 550800      |
# | train/                  |             |
# |    approx_kl            | 0.003095724 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.795      |
# |    explained_variance   | 0.0663      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 242         |
# |    n_updates            | 1520        |
# |    policy_gradient_loss | -0.00317    |
# |    value_loss           | 385         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 54           |
# |    time_elapsed         | 26263        |
# |    total_timesteps      | 554400       |
# | train/                  |              |
# |    approx_kl            | 0.0052828537 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.79        |
# |    explained_variance   | 0.0699       |
# ...
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 83          |
# |    time_elapsed         | 40466       |
# |    total_timesteps      | 658800      |
# | train/                  |             |
# |    approx_kl            | 0.006319618 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.0551      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 225         |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.00431    |
# |    value_loss           | 373         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 84           |
# |    time_elapsed         | 40953        |
# |    total_timesteps      | 662400       |
# | train/                  |              |
# |    approx_kl            | 0.0054626768 |
# |    clip_fraction        | 0.0674       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.822       |
# |    explained_variance   | 0.0646       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 98.6         |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.00658     |
# |    value_loss           | 370          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 85          |
# |    time_elapsed         | 41445       |
# |    total_timesteps      | 666000      |
# | train/                  |             |
# |    approx_kl            | 0.006042754 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0.0654      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 278         |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 367         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 86          |
# |    time_elapsed         | 41937       |
# |    total_timesteps      | 669600      |
# | train/                  |             |
# |    approx_kl            | 0.004524379 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.069       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 181         |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 363         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 87          |
# |    time_elapsed         | 42429       |
# |    total_timesteps      | 673200      |
# | train/                  |             |
# |    approx_kl            | 0.005011236 |
# |    clip_fraction        | 0.0621      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 182         |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00524    |
# |    value_loss           | 404         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 88          |
# |    time_elapsed         | 42919       |
# |    total_timesteps      | 676800      |
# | train/                  |             |
# |    approx_kl            | 0.006785381 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 0.0357      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.1        |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 375         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 89           |
# |    time_elapsed         | 43410        |
# |    total_timesteps      | 680400       |
# | train/                  |              |
# |    approx_kl            | 0.0075943153 |
# |    clip_fraction        | 0.0887       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.0837       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 241          |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.00577     |
# |    value_loss           | 358          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 90           |
# |    time_elapsed         | 43900        |
# |    total_timesteps      | 684000       |
# | train/                  |              |
# |    approx_kl            | 0.0074825473 |
# |    clip_fraction        | 0.0865       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | 0.0472       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 80.6         |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.00781     |
# |    value_loss           | 380          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 91           |
# |    time_elapsed         | 44393        |
# |    total_timesteps      | 687600       |
# | train/                  |              |
# |    approx_kl            | 0.0077288686 |
# |    clip_fraction        | 0.0805       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.797       |
# |    explained_variance   | 0.0447       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 528          |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00497     |
# |    value_loss           | 380          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 92           |
# |    time_elapsed         | 44886        |
# |    total_timesteps      | 691200       |
# | train/                  |              |
# |    approx_kl            | 0.0060001854 |
# |    clip_fraction        | 0.0653       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.77        |
# |    explained_variance   | 0.0465       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 136          |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00372     |
# |    value_loss           | 379          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 93          |
# |    time_elapsed         | 45378       |
# |    total_timesteps      | 694800      |
# | train/                  |             |
# |    approx_kl            | 0.007486863 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.821      |
# |    explained_variance   | 0.0619      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.5        |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 373         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 256        |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 94         |
# |    time_elapsed         | 45880      |
# |    total_timesteps      | 698400     |
# | train/                  |            |
# |    approx_kl            | 0.00460112 |
# |    clip_fraction        | 0.0631     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.815     |
# |    explained_variance   | 0.0447     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 403        |
# |    n_updates            | 1930       |
# |    policy_gradient_loss | -0.00394   |
# |    value_loss           | 382        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 95           |
# |    time_elapsed         | 46372        |
# |    total_timesteps      | 702000       |
# | train/                  |              |
# |    approx_kl            | 0.0046957596 |
# |    clip_fraction        | 0.0634       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.815       |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 88.9         |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00388     |
# |    value_loss           | 387          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 96           |
# |    time_elapsed         | 46872        |
# |    total_timesteps      | 705600       |
# | train/                  |              |
# |    approx_kl            | 0.0064633964 |
# |    clip_fraction        | 0.0806       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.0727       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 209          |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.00583     |
# |    value_loss           | 398          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 97           |
# |    time_elapsed         | 47373        |
# |    total_timesteps      | 709200       |
# | train/                  |              |
# |    approx_kl            | 0.0065409364 |
# |    clip_fraction        | 0.0755       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.843       |
# |    explained_variance   | 0.0631       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.8         |
# |    n_updates            | 1960         |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 388          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 98          |
# |    time_elapsed         | 47865       |
# |    total_timesteps      | 712800      |
# | train/                  |             |
# |    approx_kl            | 0.006451144 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.0457      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.1        |
# |    n_updates            | 1970        |
# |    policy_gradient_loss | -0.00401    |
# |    value_loss           | 382         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 99          |
# |    time_elapsed         | 48360       |
# |    total_timesteps      | 716400      |
# | train/                  |             |
# |    approx_kl            | 0.005461857 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.0682      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 287         |
# |    n_updates            | 1980        |
# |    policy_gradient_loss | -0.00425    |
# |    value_loss           | 373         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 100          |
# |    time_elapsed         | 48852        |
# |    total_timesteps      | 720000       |
# | train/                  |              |
# |    approx_kl            | 0.0059921746 |
# |    clip_fraction        | 0.0699       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | 0.0643       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 203          |
# |    n_updates            | 1990         |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 390          |
# ------------------------------------------

# %%
model.learn(total_timesteps=360000, tb_log_name="third_run", reset_num_timesteps=False)
model.save("PPO_square_no_bonus_3")
# Out:
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 5           |
# |    iterations           | 1           |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 723600      |
# | train/                  |             |
# |    approx_kl            | 0.006968022 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 201         |
# |    n_updates            | 2000        |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 369         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 2            |
# |    time_elapsed         | 1155         |
# |    total_timesteps      | 727200       |
# | train/                  |              |
# |    approx_kl            | 0.0066300235 |
# |    clip_fraction        | 0.0815       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.891       |
# |    explained_variance   | 0.0814       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 242          |
# |    n_updates            | 2010         |
# |    policy_gradient_loss | -0.00884     |
# |    value_loss           | 376          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 3            |
# |    time_elapsed         | 1718         |
# |    total_timesteps      | 730800       |
# | train/                  |              |
# |    approx_kl            | 0.0049148365 |
# |    clip_fraction        | 0.0618       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.846       |
# |    explained_variance   | 0.0141       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60           |
# |    n_updates            | 2020         |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 364          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 246         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 4           |
# |    time_elapsed         | 2255        |
# |    total_timesteps      | 734400      |
# | train/                  |             |
# |    approx_kl            | 0.006225443 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | 0.0587      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 253         |
# |    n_updates            | 2030        |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 352         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 5           |
# |    time_elapsed         | 2816        |
# |    total_timesteps      | 738000      |
# | train/                  |             |
# |    approx_kl            | 0.008266881 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 0.0282      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 322         |
# |    n_updates            | 2040        |
# |    policy_gradient_loss | -0.00572    |
# |    value_loss           | 351         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 6           |
# |    time_elapsed         | 3348        |
# |    total_timesteps      | 741600      |
# | train/                  |             |
# |    approx_kl            | 0.009032454 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.0354      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 275         |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | -0.0043     |
# |    value_loss           | 351         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 7           |
# |    time_elapsed         | 3852        |
# |    total_timesteps      | 745200      |
# | train/                  |             |
# |    approx_kl            | 0.006034607 |
# |    clip_fraction        | 0.0755      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 0.0494      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.2        |
# |    n_updates            | 2060        |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 367         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 8           |
# |    time_elapsed         | 4353        |
# |    total_timesteps      | 748800      |
# | train/                  |             |
# |    approx_kl            | 0.007993322 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | 0.0719      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.5        |
# |    n_updates            | 2070        |
# |    policy_gradient_loss | -0.00438    |
# |    value_loss           | 363         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 9           |
# |    time_elapsed         | 4885        |
# |    total_timesteps      | 752400      |
# | train/                  |             |
# |    approx_kl            | 0.005913533 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | 0.0768      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 159         |
# |    n_updates            | 2080        |
# |    policy_gradient_loss | -0.00453    |
# |    value_loss           | 376         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 10          |
# |    time_elapsed         | 5412        |
# |    total_timesteps      | 756000      |
# | train/                  |             |
# |    approx_kl            | 0.006313205 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.0843      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 356         |
# |    n_updates            | 2090        |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 379         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 11           |
# |    time_elapsed         | 5932         |
# |    total_timesteps      | 759600       |
# | train/                  |              |
# |    approx_kl            | 0.0059581026 |
# |    clip_fraction        | 0.0722       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.917       |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 485          |
# |    n_updates            | 2100         |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 373          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 12          |
# |    time_elapsed         | 6450        |
# |    total_timesteps      | 763200      |
# | train/                  |             |
# |    approx_kl            | 0.005445428 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.875      |
# |    explained_variance   | 0.0525      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 168         |
# |    n_updates            | 2110        |
# |    policy_gradient_loss | -0.00591    |
# |    value_loss           | 371         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 13          |
# |    time_elapsed         | 6964        |
# |    total_timesteps      | 766800      |
# | train/                  |             |
# |    approx_kl            | 0.005290367 |
# |    clip_fraction        | 0.0661      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.0497      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 263         |
# |    n_updates            | 2120        |
# |    policy_gradient_loss | -0.00389    |
# |    value_loss           | 366         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 14          |
# |    time_elapsed         | 7474        |
# |    total_timesteps      | 770400      |
# | train/                  |             |
# |    approx_kl            | 0.009057207 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | 0.0808      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 242         |
# |    n_updates            | 2130        |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 363         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 15          |
# |    time_elapsed         | 7996        |
# |    total_timesteps      | 774000      |
# | train/                  |             |
# |    approx_kl            | 0.006490344 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.0969      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.5        |
# |    n_updates            | 2140        |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 383         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 16          |
# |    time_elapsed         | 8514        |
# |    total_timesteps      | 777600      |
# | train/                  |             |
# |    approx_kl            | 0.004821947 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 185         |
# |    n_updates            | 2150        |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 364         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 17           |
# |    time_elapsed         | 9033         |
# |    total_timesteps      | 781200       |
# | train/                  |              |
# |    approx_kl            | 0.0056986213 |
# |    clip_fraction        | 0.0788       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.0125       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 242          |
# |    n_updates            | 2160         |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 360          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 18           |
# |    time_elapsed         | 9568         |
# |    total_timesteps      | 784800       |
# | train/                  |              |
# |    approx_kl            | 0.0054660053 |
# |    clip_fraction        | 0.0717       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.914       |
# |    explained_variance   | 0.0572       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 187          |
# |    n_updates            | 2170         |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 359          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 19          |
# |    time_elapsed         | 10118       |
# |    total_timesteps      | 788400      |
# | train/                  |             |
# |    approx_kl            | 0.006726215 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 0.0561      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.2        |
# |    n_updates            | 2180        |
# |    policy_gradient_loss | -0.00616    |
# |    value_loss           | 362         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 20           |
# |    time_elapsed         | 10694        |
# |    total_timesteps      | 792000       |
# | train/                  |              |
# |    approx_kl            | 0.0063509927 |
# |    clip_fraction        | 0.0686       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.0952       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 178          |
# |    n_updates            | 2190         |
# |    policy_gradient_loss | -0.00512     |
# |    value_loss           | 382          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 21          |
# |    time_elapsed         | 11280       |
# |    total_timesteps      | 795600      |
# | train/                  |             |
# |    approx_kl            | 0.006174466 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 145         |
# |    n_updates            | 2200        |
# |    policy_gradient_loss | -0.00653    |
# |    value_loss           | 382         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 22          |
# |    time_elapsed         | 11843       |
# |    total_timesteps      | 799200      |
# | train/                  |             |
# |    approx_kl            | 0.006731595 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.832      |
# |    explained_variance   | 0.0151      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.4        |
# |    n_updates            | 2210        |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 368         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 23          |
# |    time_elapsed         | 12344       |
# |    total_timesteps      | 802800      |
# | train/                  |             |
# |    approx_kl            | 0.005920605 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.0427      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.3        |
# |    n_updates            | 2220        |
# |    policy_gradient_loss | -0.00551    |
# |    value_loss           | 377         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 256          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 24           |
# |    time_elapsed         | 12846        |
# |    total_timesteps      | 806400       |
# | train/                  |              |
# |    approx_kl            | 0.0058868434 |
# |    clip_fraction        | 0.0797       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.865       |
# |    explained_variance   | 0.0389       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 147          |
# |    n_updates            | 2230         |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 375          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 25          |
# |    time_elapsed         | 13357       |
# |    total_timesteps      | 810000      |
# | train/                  |             |
# |    approx_kl            | 0.004854404 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.07        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 193         |
# |    n_updates            | 2240        |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 378         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 26           |
# |    time_elapsed         | 13862        |
# |    total_timesteps      | 813600       |
# | train/                  |              |
# |    approx_kl            | 0.0050054784 |
# |    clip_fraction        | 0.0782       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.862       |
# |    explained_variance   | 0.0399       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 235          |
# |    n_updates            | 2250         |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 374          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 27          |
# |    time_elapsed         | 14357       |
# |    total_timesteps      | 817200      |
# | train/                  |             |
# |    approx_kl            | 0.006079875 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.0523      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 165         |
# |    n_updates            | 2260        |
# |    policy_gradient_loss | -0.00478    |
# |    value_loss           | 381         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 28           |
# |    time_elapsed         | 14855        |
# |    total_timesteps      | 820800       |
# | train/                  |              |
# |    approx_kl            | 0.0059496886 |
# |    clip_fraction        | 0.0926       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.851       |
# |    explained_variance   | 0.0278       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 303          |
# |    n_updates            | 2270         |
# |    policy_gradient_loss | -0.00557     |
# |    value_loss           | 370          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 256          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 29           |
# |    time_elapsed         | 15359        |
# |    total_timesteps      | 824400       |
# | train/                  |              |
# |    approx_kl            | 0.0055651385 |
# |    clip_fraction        | 0.0731       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.045        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.5         |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -0.00417     |
# |    value_loss           | 370          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 30          |
# |    time_elapsed         | 15865       |
# |    total_timesteps      | 828000      |
# | train/                  |             |
# |    approx_kl            | 0.004551393 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | 0.0365      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 193         |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 369         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 259          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 31           |
# |    time_elapsed         | 16374        |
# |    total_timesteps      | 831600       |
# | train/                  |              |
# |    approx_kl            | 0.0062588695 |
# |    clip_fraction        | 0.0772       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.87        |
# |    explained_variance   | 0.0318       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.8         |
# |    n_updates            | 2300         |
# |    policy_gradient_loss | -0.00546     |
# |    value_loss           | 374          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 32          |
# |    time_elapsed         | 16884       |
# |    total_timesteps      | 835200      |
# | train/                  |             |
# |    approx_kl            | 0.010957929 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | 0.0269      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 108         |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.005      |
# |    value_loss           | 378         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 259          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 33           |
# |    time_elapsed         | 17394        |
# |    total_timesteps      | 838800       |
# | train/                  |              |
# |    approx_kl            | 0.0068153134 |
# |    clip_fraction        | 0.0842       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.913       |
# |    explained_variance   | 0.045        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 253          |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 367          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 34           |
# |    time_elapsed         | 17905        |
# |    total_timesteps      | 842400       |
# | train/                  |              |
# |    approx_kl            | 0.0065767085 |
# |    clip_fraction        | 0.078        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.932       |
# |    explained_variance   | 0.0825       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 247          |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.00427     |
# |    value_loss           | 395          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 35           |
# |    time_elapsed         | 18414        |
# |    total_timesteps      | 846000       |
# | train/                  |              |
# |    approx_kl            | 0.0068268557 |
# |    clip_fraction        | 0.089        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.944       |
# |    explained_variance   | 0.0345       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 316          |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | -0.00488     |
# |    value_loss           | 367          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 36           |
# |    time_elapsed         | 18923        |
# |    total_timesteps      | 849600       |
# | train/                  |              |
# |    approx_kl            | 0.0085305255 |
# |    clip_fraction        | 0.094        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.981       |
# |    explained_variance   | 0.0443       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 227          |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.00728     |
# |    value_loss           | 365          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 37          |
# |    time_elapsed         | 19431       |
# |    total_timesteps      | 853200      |
# | train/                  |             |
# |    approx_kl            | 0.006090221 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | 0.0616      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 238         |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00449    |
# |    value_loss           | 359         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 38          |
# |    time_elapsed         | 19940       |
# |    total_timesteps      | 856800      |
# | train/                  |             |
# |    approx_kl            | 0.007188455 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.0127      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.9        |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 369         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 39           |
# |    time_elapsed         | 20447        |
# |    total_timesteps      | 860400       |
# | train/                  |              |
# |    approx_kl            | 0.0066265413 |
# |    clip_fraction        | 0.0831       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.976       |
# |    explained_variance   | 0.0319       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 284          |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.00424     |
# |    value_loss           | 369          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 40          |
# |    time_elapsed         | 20956       |
# |    total_timesteps      | 864000      |
# | train/                  |             |
# |    approx_kl            | 0.006308432 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | 0.0534      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.2        |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 357         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 41           |
# |    time_elapsed         | 21463        |
# |    total_timesteps      | 867600       |
# | train/                  |              |
# |    approx_kl            | 0.0066629695 |
# |    clip_fraction        | 0.0856       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | 0.0384       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 137          |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | -0.00497     |
# |    value_loss           | 364          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 42           |
# |    time_elapsed         | 21970        |
# |    total_timesteps      | 871200       |
# | train/                  |              |
# |    approx_kl            | 0.0050851135 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.994       |
# |    explained_variance   | 0.0518       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 451          |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.00397     |
# |    value_loss           | 349          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 43           |
# |    time_elapsed         | 22480        |
# |    total_timesteps      | 874800       |
# | train/                  |              |
# |    approx_kl            | 0.0062969676 |
# |    clip_fraction        | 0.0785       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.976       |
# |    explained_variance   | 0.0279       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 332          |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.00428     |
# |    value_loss           | 358          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 44           |
# |    time_elapsed         | 22989        |
# |    total_timesteps      | 878400       |
# | train/                  |              |
# |    approx_kl            | 0.0058966056 |
# |    clip_fraction        | 0.0795       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.988       |
# |    explained_variance   | 0.0398       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.5         |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.00594     |
# |    value_loss           | 351          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 45          |
# |    time_elapsed         | 23499       |
# |    total_timesteps      | 882000      |
# | train/                  |             |
# |    approx_kl            | 0.007830994 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.942      |
# |    explained_variance   | 0.0442      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 360         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 46          |
# |    time_elapsed         | 24005       |
# |    total_timesteps      | 885600      |
# | train/                  |             |
# |    approx_kl            | 0.006189929 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.04        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.2        |
# |    n_updates            | 2450        |
# |    policy_gradient_loss | -0.00576    |
# |    value_loss           | 348         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 47          |
# |    time_elapsed         | 24511       |
# |    total_timesteps      | 889200      |
# | train/                  |             |
# |    approx_kl            | 0.006427122 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.039       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 194         |
# |    n_updates            | 2460        |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 351         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 48           |
# |    time_elapsed         | 25014        |
# |    total_timesteps      | 892800       |
# | train/                  |              |
# |    approx_kl            | 0.0073193954 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.953       |
# |    explained_variance   | 0.0367       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 251          |
# |    n_updates            | 2470         |
# |    policy_gradient_loss | -0.00706     |
# |    value_loss           | 350          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 49          |
# |    time_elapsed         | 25517       |
# |    total_timesteps      | 896400      |
# | train/                  |             |
# |    approx_kl            | 0.008972216 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.973      |
# |    explained_variance   | 0.0423      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.2        |
# |    n_updates            | 2480        |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 350         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 50           |
# |    time_elapsed         | 26018        |
# |    total_timesteps      | 900000       |
# | train/                  |              |
# |    approx_kl            | 0.0051833843 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | 0.0632       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 247          |
# |    n_updates            | 2490         |
# |    policy_gradient_loss | -0.00521     |
# |    value_loss           | 352          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 51          |
# |    time_elapsed         | 26520       |
# |    total_timesteps      | 903600      |
# | train/                  |             |
# |    approx_kl            | 0.007239916 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.6        |
# |    n_updates            | 2500        |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 357         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 52          |
# |    time_elapsed         | 27027       |
# |    total_timesteps      | 907200      |
# | train/                  |             |
# |    approx_kl            | 0.008478385 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 192         |
# |    n_updates            | 2510        |
# |    policy_gradient_loss | -0.00622    |
# |    value_loss           | 348         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 53           |
# |    time_elapsed         | 27527        |
# |    total_timesteps      | 910800       |
# | train/                  |              |
# |    approx_kl            | 0.0082983775 |
# |    clip_fraction        | 0.0897       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.964       |
# |    explained_variance   | 0.0546       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 535          |
# |    n_updates            | 2520         |
# |    policy_gradient_loss | -0.00634     |
# |    value_loss           | 348          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 245         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 54          |
# |    time_elapsed         | 28027       |
# |    total_timesteps      | 914400      |
# | train/                  |             |
# |    approx_kl            | 0.005555425 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.0885      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.2        |
# |    n_updates            | 2530        |
# ...
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 83          |
# |    time_elapsed         | 42520       |
# |    total_timesteps      | 1018800     |
# | train/                  |             |
# |    approx_kl            | 0.005004839 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | 0.0504      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.3        |
# |    n_updates            | 2820        |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 356         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 84           |
# |    time_elapsed         | 43010        |
# |    total_timesteps      | 1022400      |
# | train/                  |              |
# |    approx_kl            | 0.0073984936 |
# |    clip_fraction        | 0.0991       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.977       |
# |    explained_variance   | 0.0873       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 240          |
# |    n_updates            | 2830         |
# |    policy_gradient_loss | -0.00739     |
# |    value_loss           | 355          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 85          |
# |    time_elapsed         | 43506       |
# |    total_timesteps      | 1026000     |
# | train/                  |             |
# |    approx_kl            | 0.006473655 |
# |    clip_fraction        | 0.0801      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 0.0648      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.3        |
# |    n_updates            | 2840        |
# |    policy_gradient_loss | -0.00671    |
# |    value_loss           | 352         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 86           |
# |    time_elapsed         | 44008        |
# |    total_timesteps      | 1029600      |
# | train/                  |              |
# |    approx_kl            | 0.0067360788 |
# |    clip_fraction        | 0.0824       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.88        |
# |    explained_variance   | 0.0699       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 95.3         |
# |    n_updates            | 2850         |
# |    policy_gradient_loss | -0.00579     |
# |    value_loss           | 368          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 87          |
# |    time_elapsed         | 44508       |
# |    total_timesteps      | 1033200     |
# | train/                  |             |
# |    approx_kl            | 0.006209838 |
# |    clip_fraction        | 0.0921      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | 0.0661      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 193         |
# |    n_updates            | 2860        |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 366         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 88          |
# |    time_elapsed         | 45003       |
# |    total_timesteps      | 1036800     |
# | train/                  |             |
# |    approx_kl            | 0.005810564 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | 0.0505      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95.4        |
# |    n_updates            | 2870        |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 352         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 89           |
# |    time_elapsed         | 45502        |
# |    total_timesteps      | 1040400      |
# | train/                  |              |
# |    approx_kl            | 0.0064254557 |
# |    clip_fraction        | 0.0758       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.892       |
# |    explained_variance   | 0.0225       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 171          |
# |    n_updates            | 2880         |
# |    policy_gradient_loss | -0.00544     |
# |    value_loss           | 357          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 90          |
# |    time_elapsed         | 46001       |
# |    total_timesteps      | 1044000     |
# | train/                  |             |
# |    approx_kl            | 0.005145296 |
# |    clip_fraction        | 0.0766      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.88       |
# |    explained_variance   | 0.0386      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 280         |
# |    n_updates            | 2890        |
# |    policy_gradient_loss | -0.00442    |
# |    value_loss           | 371         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 91           |
# |    time_elapsed         | 46498        |
# |    total_timesteps      | 1047600      |
# | train/                  |              |
# |    approx_kl            | 0.0072090686 |
# |    clip_fraction        | 0.0952       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.926       |
# |    explained_variance   | 0.0546       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 269          |
# |    n_updates            | 2900         |
# |    policy_gradient_loss | -0.00676     |
# |    value_loss           | 349          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 92           |
# |    time_elapsed         | 46998        |
# |    total_timesteps      | 1051200      |
# | train/                  |              |
# |    approx_kl            | 0.0073063583 |
# |    clip_fraction        | 0.0913       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.0517       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 86.1         |
# |    n_updates            | 2910         |
# |    policy_gradient_loss | -0.00555     |
# |    value_loss           | 378          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 93          |
# |    time_elapsed         | 47495       |
# |    total_timesteps      | 1054800     |
# | train/                  |             |
# |    approx_kl            | 0.005583895 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.0788      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 343         |
# |    n_updates            | 2920        |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 368         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 94           |
# |    time_elapsed         | 47993        |
# |    total_timesteps      | 1058400      |
# | train/                  |              |
# |    approx_kl            | 0.0059054056 |
# |    clip_fraction        | 0.084        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | 0.0324       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.8         |
# |    n_updates            | 2930         |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 360          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 95           |
# |    time_elapsed         | 48490        |
# |    total_timesteps      | 1062000      |
# | train/                  |              |
# |    approx_kl            | 0.0085618505 |
# |    clip_fraction        | 0.0721       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.944       |
# |    explained_variance   | 0.0459       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.7         |
# |    n_updates            | 2940         |
# |    policy_gradient_loss | -0.00446     |
# |    value_loss           | 366          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 96           |
# |    time_elapsed         | 48988        |
# |    total_timesteps      | 1065600      |
# | train/                  |              |
# |    approx_kl            | 0.0076915193 |
# |    clip_fraction        | 0.0873       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.985       |
# |    explained_variance   | 0.0579       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 555          |
# |    n_updates            | 2950         |
# |    policy_gradient_loss | -0.00554     |
# |    value_loss           | 372          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 97          |
# |    time_elapsed         | 49485       |
# |    total_timesteps      | 1069200     |
# | train/                  |             |
# |    approx_kl            | 0.004586129 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.0631      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 144         |
# |    n_updates            | 2960        |
# |    policy_gradient_loss | -0.00407    |
# |    value_loss           | 373         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 98           |
# |    time_elapsed         | 49982        |
# |    total_timesteps      | 1072800      |
# | train/                  |              |
# |    approx_kl            | 0.0068206238 |
# |    clip_fraction        | 0.0856       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.929       |
# |    explained_variance   | 0.055        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.7         |
# |    n_updates            | 2970         |
# |    policy_gradient_loss | -0.00485     |
# |    value_loss           | 382          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 99           |
# |    time_elapsed         | 50480        |
# |    total_timesteps      | 1076400      |
# | train/                  |              |
# |    approx_kl            | 0.0068611195 |
# |    clip_fraction        | 0.0806       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.0688       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.2         |
# |    n_updates            | 2980         |
# |    policy_gradient_loss | -0.00639     |
# |    value_loss           | 377          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 100          |
# |    time_elapsed         | 50976        |
# |    total_timesteps      | 1080000      |
# | train/                  |              |
# |    approx_kl            | 0.0058351387 |
# |    clip_fraction        | 0.0821       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.915       |
# |    explained_variance   | 0.0617       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 136          |
# |    n_updates            | 2990         |
# |    policy_gradient_loss | -0.00527     |
# |    value_loss           | 367          |
# ------------------------------------------

# %%
model.learn(total_timesteps=360000, tb_log_name="fourth_run", reset_num_timesteps=False)
model.save("PPO_tao9_bonus_4")

# %%
model.learn(total_timesteps=360000, tb_log_name="fifth_run", reset_num_timesteps=False)
model.save("PPO_tao9_bonus_5")

# %%
model.learn(total_timesteps=200000, tb_log_name="sixth_run_14", reset_num_timesteps=False)
model.save("PPO_test14_modflow_multiInflow_coast_6")

# %%
del model

# %%
model = PPO.load("PPO_tao")
env = gym.make('pumpingAllocation-v5')

#Pick scenerio
scenerio = 8

p = [0]*10
p[scenerio-1] = 1
#p = [0, 0.3, 0.3, 0.4,0]

env.river_p = p
env.demands_p = [1,0]

SW, GW, Sup, D = [], [], [], []
deficit=[]
S, h, inflow = [], [], []
Z_mean = []
rewards = []
env.ifRandtt = False

for i in range(1):
    print('----------test',i+1,'start-------------')
    state = env.reset()
    total_step=0
    while True:
        action, _states = model.predict(state,deterministic=True )
        #print(action, _states)
        next_state, reward, done, info = env.step(action)
        #print(next_state,reward,done)
        
        #還原標準化
        month = (total_step//3)%12+1
        #month = (state[3]+1)/2*11+1
        storage = (state[0]+1)/2*23500
        Zmin_before = (state[1]+1)/2*100-100
        Zmin_after = (next_state[1]+1)/2*100-100
        demand = (state[2]+1)/2*(3006.85-1201.95+400)+1300-200
        inf = (state[4]+1)/2*(30721.8-336.2+200)+336.2-200
        
        sw = action[0]*300
        gw = action[1]*216*240*20/10000
        
        print(f'{month:2.0f}月, 第{total_step+1:2.0f}旬, 水庫水量:{storage:5.0f}, 水位(前、後):{Zmin_before:5.1f}→{Zmin_after:4.1f}, Action:{action}, SW、GW:[{sw:3.0f}, {gw:3.0f}], 需水量:{demand:4.0f}, Reward: {reward:.1f}')
        
        SW.append(sw)
        GW.append(gw)
        Sup.append(sw+gw)
        D.append(demand)
        deficit.append(max(0,demand-sw-gw))
        S.append(storage)
        h.append(Zmin_before)
        inflow.append(inf)
        rewards.append(reward)
        
        state = next_state
        total_step+=1

        if done:
            break

# %%
import matplotlib.pyplot as plt
import pandas as pd
end=180

df = pd.DataFrame({'SW':SW[:end],
                   'GW':GW[:end],
                   'Supply':Sup[:end],
                   'Demand':D[:end],
                   'ith period of tendays':[i for i in range(1,end+1)],
                   'deficit':deficit[:end],
                   'S':S[:end],
                   'h':h[:end],
                   'In':inflow[:end],
                   'deficit_rate':[(b-a)/b*100 for a,b in zip(Sup[:end],D[:end])],
                   'reward':rewards[:end]
                  }) 


ax = df[['SW','GW']].plot(kind='bar', stacked=True, figsize=(18,6), width=0.7,
                          xlim=[1,180], ylim=[0,4100], xticks=[9*i for i in range(1,21)], fontsize=14)
df['Demand'].plot(kind='line', color='#FF0000', lw=2, xlim=[1,180],legend=True)
df['Supply'].plot(kind='line', style='g.-', lw=2, xlim=[1,180],legend=True)
ax.set_title('SW+GW_Scenerio_{}'.format(scenerio), fontsize=16)
ax.set_xlabel("tendays", fontsize=14)
ax.set_ylabel("m^3", fontsize=14)
ax.legend()

# %%
#reward
ax = df['reward'].plot(kind='bar', figsize=(15,5), lw=1.5, xlim=[1,180], ylim=[-3,3], 
                        style='r.-', xticks=[9*i for i in range(1,21)], fontsize=10)
#ax.set_title('deficit_rate', fontsize=16)
ax.set_xlabel("tendays", fontsize=14)
ax.set_ylabel("reward", fontsize=14)

# %%
ax = df[['S','In']].plot(kind='line', lw='2', figsize=(12,7),xlim=[1,180], ylim=[0,31000], xticks=[9*i for i in range(1,21)])
ax.set_title('Storage & Inflow _Scenerio_{}'.format(scenerio), fontsize=16)
ax.set_xlabel("tendays", fontsize=14)
ax.set_ylabel("m^3", fontsize=14)
ax.legend()

# %%
ax = df['GW'].plot(kind='area', color='#00bbff', figsize=(12,7), xlim=[1,180], xticks=[9*i for i in range(1,21)], legend=True)
ax2 = df['h'].plot(kind='line', secondary_y = True,  lw=2, color='#FF0000', legend=True)
ax.set_title('Groundwater Head & Pumping _Scenerio_{}'.format(scenerio), fontsize=16)
ax.set_xlabel("tendays", fontsize=14)
ax.set_ylabel("groundwater pumping (m^3)", fontsize=14)
ax2.set_ylabel("groundwater head (m)", fontsize=14)
