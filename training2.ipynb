# %%
import numpy as np  # for array stuff and random
import random
import matplotlib.pyplot as plt  # for graphing our mean rewards over time
from matplotlib import style  # to make pretty charts because it matters.
import os

import torch
import gym
from gym import spaces
from gym import envs
from gym.utils import seeding, EzPickle

# %%
seed = 543 # Do not change this
def fix(env, seed):
    env.seed(seed)
    env.action_space.seed(seed)
    #torch.manual_seed(seed)
    #torch.cuda.manual_seed(seed)
    #torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    #torch.set_deterministic(True)
    #torch.backends.cudnn.benchmark = False
    #torch.backends.cudnn.deterministic = True

# %%
from stable_baselines3 import PPO
from stable_baselines3 import A2C
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(

# %%
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.logger import configure

env = gym.make('pumpingAllocation-v4')
#Parallel environments
#env = make_vec_env('pumpingAllocation-v1', n_envs=8)
fix(env, seed)

tmp_path = "./PPO_pumpAllo_modflow_multScen_multiInflow_coast_tensorboard/"
# set up logger
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

model = PPO("MlpPolicy", env, verbose=1, n_steps=3600, seed=seed)
model.set_logger(new_logger)
model.learn(total_timesteps=3000)
# Out:
# Logging to ./PPO_pumpAllo_modflow_multScen_multiInflow_coast_tensorboard/
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\stable_baselines3\ppo\ppo.py:137: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3600`, after every 56 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3600 and n_envs=1)
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -75.4    |
# | time/              |          |
# |    fps             | 5        |
# |    iterations      | 1        |
# |    time_elapsed    | 652      |
# |    total_timesteps | 3600     |
# ---------------------------------

# %%
model.save("PPO_test_modflow_multiInflow_coast_1")
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model.learn(total_timesteps=3500)
model.save("PPO_test_modflow_multiInflow_coast_2")
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -50.1       |
# | time/                   |             |
# |    fps                  | 5           |
# |    iterations           | 1           |
# |    time_elapsed         | 614         |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.013607097 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# ...

# %%
model.learn(total_timesteps=7000)
model.save("PPO_test_modflow_multiInflow_coast_3")
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -14.9       |
# | time/                   |             |
# |    fps                  | 5           |
# |    iterations           | 1           |
# |    time_elapsed         | 619         |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.016624037 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# ...

# %%
model.learn(total_timesteps=10000)
model.save("PPO_test_modflow_multiInflow_coast_4")
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 32.2        |
# | time/                   |             |
# |    fps                  | 5           |
# |    iterations           | 1           |
# |    time_elapsed         | 668         |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.017100012 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# ...

# %%
model.learn(total_timesteps=20000)
model.save("PPO_test_modflow_multiInflow_coast_5")
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 89.9        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 1           |
# |    time_elapsed         | 734         |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.013877843 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# ...

# %%
model.learn(total_timesteps=40000)
model.save("PPO_test_modflow_multiInflow_coast_6")
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 1           |
# |    time_elapsed         | 868         |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.009920766 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# ...

# %%
model.learn(total_timesteps=80000)
model.save("PPO_test_modflow_multiInflow_coast_7")
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 1           |
# |    time_elapsed         | 1324        |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.009850664 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# ...

# %%
model.learn(total_timesteps=160000)
model.save("PPO_test_modflow_multiInflow_coast_8")
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-7baf94a67876> in <module>
# ----> 1 model.learn(total_timesteps=160000)
#       2 model.save("PPO_test_modflow_multiInflow_coast_8")
#
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     297     ) -> "PPO":
#     298
# ...

# %%
model.learn(total_timesteps=320000)
model.save("PPO_test_modflow_multiInflow_coast_9")

# %%
model.learn(total_timesteps=360000)
model.save("PPO_test_modflow_multiInflow_coast_10")
